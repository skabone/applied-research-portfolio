# %% [markdown]
# # Titanic Passenger Survival Classification
#
# This notebook is an executed companion to `04_Source_Code.py`. The source workflow reads the project-local Kaggle files, rebuilds the engineered feature table, evaluates the model set, writes the submission file, and refreshes the project figures.

# %%
from pathlib import Path
import runpy

project_dir = Path.cwd()
runpy.run_path(str(project_dir / '04_Source_Code.py'), run_name='__main__')
# Out:
# Titanic survival classification workflow
# Training rows: 891 | Test rows: 418
# Training survival rate: 38.4%
#
# Cross-validated model comparison:
#                Model AccuracyMean AccuracySD BalancedAccuracyMean BalancedAccuracySD
#    Gradient Boosting        0.838      0.026                0.818              0.029
#        Random Forest        0.832      0.004                0.813              0.006
# Hard-Voting Ensemble        0.829      0.015                0.816              0.016
#  Logistic Regression        0.828      0.014                0.815              0.018
# Gaussian Naive Bayes        0.807      0.011                0.811              0.015
#        Decision Tree        0.800      0.018                0.775              0.023
#
# Out-of-fold ensemble confusion matrix: [[479, 70], [82, 260]]
# Predicted survival rate in test file: 40.4%
# Best recorded Kaggle public leaderboard score: 0.79186
# Figures written to: docs/figures
# ...

# %% [markdown]
# ## Rendered Evidence
#
# The project report interprets the full results. The figures below provide the visual evidence used in that interpretation.
#
# ![Survival by sex and class](docs/figures/fig01-survival-by-sex-class.png)
#
# ![Missingness profile](docs/figures/fig02-missingness-profile.png)
#
# ![Submission history](docs/figures/fig03-submission-history.png)
#
# ![Model comparison](docs/figures/fig04-cross-validated-model-comparison.png)
#
# ![Feature importance](docs/figures/fig05-feature-importance.png)
#
# ![Confusion matrix](docs/figures/fig06-confusion-matrix.png)
