# %% [markdown]
# # College Institutional Profile Modeling - Notebook Companion
#
# This notebook is the GitHub-viewable companion for Project 07. The reproducible source is `04_Source_Code.py`; running that script from this folder regenerates all six figures in `docs/figures/`.
#
# The saved output below is from the verified Project 07 run performed during the manual runbook pass.

# %%
# Reproduce the full workflow from the project folder.
# This script reads data/College_Data.csv and writes every figure to docs/figures/.
import runpy
runpy.run_path("04_Source_Code.py", run_name="__main__")
# Out:
# ...
# COLLEGE INSTITUTIONAL PROFILE MODELING - VERIFIED RESULTS
# ...
# N institutions: 777
# Private institutions: 565 (72.7%)
# Public institutions:  212 (27.3%)
#
# Graduation-rate regression
#   R-squared: 0.487
#   RMSE: 10.98 graduation-rate points
#   Top coefficients by absolute value:
#     Private_bin: +3.322
#     perc.alumni: +0.294
#     Top10perc: +0.254
#     S.F.Ratio: +0.102
#
# Classification model comparison
#   SVM (RBF kernel): accuracy=0.937, sd=0.014
#   Logistic regression: accuracy=0.936, sd=0.012
#   Random forest: accuracy=0.929, sd=0.012
#   Decision tree: accuracy=0.901, sd=0.011
#   Top random forest importances:
#     Outstate: 0.279
#     Enroll: 0.193
#     Accept: 0.110
#     S.F.Ratio: 0.091
#     Apps: 0.081
#
# Unsupervised structure
#   k-means adjusted Rand index vs Private/Public: -0.023
#   k-means cluster table:
# Private_bin        0    1
# k-means cluster
# 0                 50  206
# 1                162  359
# ...

# %% [markdown]
# ## Key Figures
#
# ![Institution type balance](docs/figures/fig01-institution-type-balance.png)
#
# ![Graduation-rate regression coefficients](docs/figures/fig02-graduation-regression-coefficients.png)
#
# ![Classification model comparison](docs/figures/fig03-classification-model-comparison.png)
#
# ![Random forest feature importance](docs/figures/fig04-random-forest-feature-importance.png)
#
# ![PCA profile map](docs/figures/fig05-pca-profile-map.png)
#
# ![PCA variance explained](docs/figures/fig06-pca-variance-explained.png)
